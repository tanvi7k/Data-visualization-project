# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import the dataset using pandas dataframe
data=pd.read_csv('/content/archive (6).zip')
data.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
#Displaying the last 5 rows of dataset
data.tail()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 4648                          4           0
# 4649                          2           1
# 4650                          5           1
# 4651                          2           0
# 4652                          4           0

# %%
#Displaying the rows and columns
data.shape
# Out:
# (4653, 9)

# %%
data.describe()
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4653.000000
# mean      0.343864
# std       0.475047
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
#Displaying Information about columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %%
#Checking null values
data.isnull().sum()
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64

# %%
#Checking unique values
data.nunique()
# Out:
# Education                     3
# JoiningYear                   7
# City                          3
# PaymentTier                   3
# Age                          20
# Gender                        2
# EverBenched                   2
# ExperienceInCurrentDomain     8
# LeaveOrNot                    2
# dtype: int64

# %%
#Finding categorical distribution of column city
data['City'].value_counts()
# Out:
# Bangalore    2228
# Pune         1268
# New Delhi    1157
# Name: City, dtype: int64

# %%
#Finding categorical distribution of column Education
data['Education'].value_counts()

# %%
#Histogram of Employees' Joining Year
data = data['JoiningYear']
plt.figure(figsize=(10, 6))
plt.hist(rdata, bins=4, color='skyblue', edgecolor='black')
plt.title("Employees joining year")
plt.xlabel("JoiningYear")
plt.ylabel("frequency")
plt.show()

# %%
data.groupby('Education').mean()
# Out:
# <ipython-input-94-4713fbb60581>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('Education').mean()
#            JoiningYear  PaymentTier        Age  ExperienceInCurrentDomain  \
# Education
# Bachelors  2014.883366     2.753124  29.422938                   2.910580
# Masters    2015.806415     2.465063  29.290951                   2.884307
# PHD        2015.050279     2.731844  29.296089                   2.910615
#
#            LeaveOrNot
# Education
# Bachelors    0.313524
# Masters      0.487973
# PHD          0.251397

# %%
#Count Plot of Gender Distribution
plt.figure(figsize=(10, 6))
sns.countplot(x=data['Gender'], color='skyblue')
plt.title("Gender count plot")
plt.xlabel("Gender")
plt.ylabel("count")
plt.show()

# %%
#Count Plot of Education Distribution
plt.figure(figsize=(10, 6))
sns.countplot(x=data['Education'], color='skyblue')
plt.title("Education of employees count plot ")
plt.xlabel("Education")
plt.ylabel("count")
plt.show()

# %%
#Bivariate Analysis
#Scatter Plot of Age vs. Experience in Current Domain (Color-coded by Gender)
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Age', y='ExperienceInCurrentDomain',hue="Gender", data=data, color='skyblue')
plt.title("Scatter plot")
plt.xlabel("Age")
plt.ylabel("Experience In Current Domain")
plt.show()

# %%
#Swarm Plot of Age vs. City (Color-coded by Gender)
plt.figure(figsize=(8, 6))
sns.swarmplot(x='City',y="Age", hue='Gender', data=data, color='Pink')
plt.title("Swarmplot")
plt.xlabel("City")
plt.ylabel("Age")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:Pink'` for same effect.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 72.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 55.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 53.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
#Barplot of Age vs. Payment Tier (Color-coded by Gender)
plt.figure(figsize=(10, 6))
sns.barplot(x='Age',y="PaymentTier", hue='Gender', data=data, ci=None, palette='Set1')
plt.xlabel("Age")
plt.ylabel("Experience In Current Domain")
plt.show()
# Out:
# <ipython-input-12-5038ad91c255>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Age',y="PaymentTier", hue='Gender', data=data, ci=None, palette='Set1')

# %%
data.corr()
# Out:
# <ipython-input-114-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                            JoiningYear  PaymentTier       Age  \
# JoiningYear                   1.000000    -0.096078  0.013165
# PaymentTier                  -0.096078     1.000000  0.007631
# Age                           0.013165     0.007631  1.000000
# ExperienceInCurrentDomain    -0.036525     0.018314 -0.134643
# LeaveOrNot                    0.181705    -0.197638 -0.051126
#
#                            ExperienceInCurrentDomain  LeaveOrNot
# JoiningYear                                -0.036525    0.181705
# PaymentTier                                 0.018314   -0.197638
# Age                                        -0.134643   -0.051126
# ExperienceInCurrentDomain                   1.000000   -0.030504
# ...

# %%
#Correlation Matrix Heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
#Calculating variance
variance = data.var()
print("Variance:")
print(variance)

covariance_matrix = data.cov()
print("\nCovariance Matrix:")
print(covariance_matrix)
# Out:
# Variance:
# JoiningYear                   3.472173
# PaymentTier                   0.315210
# Age                          23.291116
# ExperienceInCurrentDomain     2.428113
# LeaveOrNot                    0.225670
# dtype: float64
#
# Covariance Matrix:
#                            JoiningYear  PaymentTier        Age  \
# JoiningYear                   3.472173    -0.100514   0.118393
# PaymentTier                  -0.100514     0.315210   0.020676
# Age                           0.118393     0.020676  23.291116
# ExperienceInCurrentDomain    -0.106052     0.016022  -1.012542
# LeaveOrNot                    0.160844    -0.052712  -0.117212
#
#                            ExperienceInCurrentDomain  LeaveOrNot
# JoiningYear                                -0.106052    0.160844
# PaymentTier                                 0.016022   -0.052712
# Age                                        -1.012542   -0.117212
# ExperienceInCurrentDomain                   2.428113   -0.022580
# ...

# %%
Bachelors_b = data[data['Education'] == 'Bachelors']

Masters_m = data[data['Education'] == 'Masters']

PhD_p = data[data['Education'] == 'PHD']

print("Bachelors:")
print(Bachelors_b)

print("\nMasters:")
print(Masters_m.head())

print("\nPhD:")
print(PhD_p.head())
# Out:
# Bachelors:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 5     Bachelors         2016  Bangalore            3   22    Male          No
# 6     Bachelors         2015  New Delhi            3   38    Male          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 4646  Bachelors         2013  Bangalore            3   25  Female          No
# 4647  Bachelors         2016       Pune            3   30    Male          No
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
#Distribution of Age of Employees with PhD (Pie Chart)
rdata = PhD_p['Age']
plt.figure(figsize=(8, 8))
plt.pie(rdata, labels=rdata, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Age of employees with PhD')
plt.axis('equal')
plt.show()

# %%
Masters_m.value_counts('ExperienceInCurrentDomain')
# Out:
# ExperienceInCurrentDomain
# 2    328
# 4    169
# 5    151
# 3    116
# 1     70
# 0     37
# 6      1
# 7      1
# dtype: int64

# %%
#Multivariate Analysis
#Pair Plot of Payment Tier, Age, and Leave Status
sns.pairplot(data[['PaymentTier', 'Age','LeaveOrNot']], diag_kind='kde')
plt.suptitle("Pair Plot", y=1.02)
plt.show()

# %%
data['info'] = data[['PaymentTier', 'Age', 'Gender', 'Education']].sum(axis=1)
data.drop(['PaymentTier', 'Age', 'Gender', 'Education'], axis=1, inplace=True)
print(data.head())
# Out:
#    JoiningYear       City EverBenched  ExperienceInCurrentDomain  LeaveOrNot  \
# 0         2017  Bangalore          No                          0           0
# 1         2013       Pune          No                          3           1
# 2         2014  New Delhi          No                          2           0
# 3         2016  Bangalore          No                          5           1
# 4         2017       Pune         Yes                          2           1
#
#    info
# 0    37
# 1    29
# 2    41
# 3    30
# 4    27
# <ipython-input-54-10bc3dd30914>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data['info'] = data[['PaymentTier', 'Age', 'Gender', 'Education']].sum(axis=1)
