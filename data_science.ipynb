# %% [markdown]
# <a href="https://colab.research.google.com/github/tanvi7k/Data-visualization-project/blob/main/data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv("/content/EV_cars.csv")
print(data)
# Out:
#      Battery                             Car_name  \
# 0       75.0  Tesla Model Y Long Range Dual Motor
# 1       57.5                        Tesla Model 3
# 2       60.5                           BYD ATTO 3
# 3       61.7               MG MG4 Electric 64 kWh
# 4       75.0  Tesla Model 3 Long Range Dual Motor
# ..       ...                                  ...
# 355     46.3      Citroen e-Jumpy Combi XL 50 kWh
# 356     46.3              Fiat E-Ulysse L2 50 kWh
# 357     46.3         Opel Vivaro-e Combi L 50 kWh
# 358     68.0          Opel Zafira-e Life M 75 kWh
# 359     46.3              Fiat E-Ulysse L3 50 kWh
#
#                                          Car_name_link  Efficiency  \
# 0    https://ev-database.org/car/1619/Tesla-Model-Y...         172
# 1       https://ev-database.org/car/1991/Tesla-Model-3         137
# 2          https://ev-database.org/car/1782/BYD-ATTO-3         183
# 3    https://ev-database.org/car/1708/MG-MG4-Electr...         171
# ...

# %%
import pandas as pd
data=pd.read_excel("/content/EV_cars.csv")
print(data)

# %%
import matplotlib.image as mpimg
import matplotlib.image as plt
img=mpimg.imread("/content/image1.jpg")
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-5436945c19be> in <cell line: 4>()
#       2 import matplotlib.image as plt
#       3 img=mpimg.imread("/content/image1.jpg")
# ----> 4 plt.imshow(img)
#
# AttributeError: module 'matplotlib.image' has no attribute 'imshow'

# %%
#Summarising data with statistically
import pandas as pd
df=pd.DataFrame({"Roll no":[1,2,3,4,5],
                 "Name":['Sam','Aditi','Riya','Aditya','Sejal'],
                 "Marks":[90,98,79,80,88],})
print(df)
# Out:
#    Roll no    Name  Marks
# 0        1     Sam     90
# 1        2   Aditi     98
# 2        3    Riya     79
# 3        4  Aditya     80
# 4        5   Sejal     88

# %%
df.isnull()
# Out:
#    Roll no   Name  Marks
# 0    False  False  False
# 1    False  False  False
# 2    False  False  False
# 3    False  False  False
# 4    False  False  False

# %%
df.isnull().sum()
# Out:
# Roll no    0
# Name       0
# Marks      0
# dtype: int64

# %%
df.describe()
# Out:
#         Roll no     Marks
# count  5.000000   5.00000
# mean   3.000000  87.00000
# std    1.581139   7.81025
# min    1.000000  79.00000
# 25%    2.000000  80.00000
# 50%    3.000000  88.00000
# 75%    4.000000  90.00000
# max    5.000000  98.00000

# %%
df.describe(include='object')
# Out:
#        Name
# count     5
# unique    5
# top     Sam
# freq      1

# %%
df.shape
# Out:
# (5, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll no  5 non-null      int64
#  1   Name     5 non-null      object
#  2   Marks    5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 248.0+ bytes

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# Roll no    5
# Name       5
# Marks      5
# dtype: int64

# %%
df.value_counts()
# Out:
# Roll no  Name    Marks
# 1        Sam     90       1
# 2        Aditi   98       1
# 3        Riya    79       1
# 4        Aditya  80       1
# 5        Sejal   88       1
# dtype: int64

# %%
df["Name"].value_counts()
# Out:
# Sam       1
# Aditi     1
# Riya      1
# Aditya    1
# Sejal     1
# Name: Name, dtype: int64

# %%
correlation=df.corr()
# Out:
# <ipython-input-48-0c9b4bd1cb53>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=df.corr()

# %%
import seaborn as sns
sns.heatmap(correlation, annot=True, fmt='.2f', cmap='Reds')
# Out:
# <Axes: >

# %%
df.var()
# Out:
# <ipython-input-63-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# Roll no     2.5
# Marks      61.0
# dtype: float64

# %%
df.mean()
# Out:
# <ipython-input-64-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Roll no     3.0
# Marks      87.0
# dtype: float64

# %% [markdown]
# mean is higher than variance

# %%
df['Marks'].var()
# Out:
# 61.0

# %%
df.cov()
# Out:
# <ipython-input-71-6f98a29763d5>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.cov()
#          Roll no  Marks
# Roll no      2.5   -5.5
# Marks       -5.5   61.0

# %%
df.corr()
# Out:
# <ipython-input-72-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           Roll no     Marks
# Roll no  1.000000 -0.445377
# Marks   -0.445377  1.000000
